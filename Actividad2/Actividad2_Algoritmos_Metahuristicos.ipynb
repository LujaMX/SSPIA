# %%
# !wget -nc https://raw.githubusercontent.com/LujaMX/SSPIA/main/Actividad1/Plots/Plot_Surf.py
# !wget -nc https://raw.githubusercontent.com/LujaMX/SSPIA/main/Actividad1/Plots/Plot_Contour.py

import matplotlib.pyplot as plt
import numpy as np
from Plot_Surf import *
from Plot_Contour import *
from IPython import display
# Out:
# --2023-09-08 03:50:28--  https://raw.githubusercontent.com/LujaMX/SSPIA/main/Actividad1/Plots/Plot_Surf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘Plot_Surf.py’
#
# Plot_Surf.py        100%[===================>]     608  --.-KB/s    in 0s
#
# 2023-09-08 03:50:29 (32.8 MB/s) - ‘Plot_Surf.py’ saved [608/608]
#
# --2023-09-08 03:50:29--  https://raw.githubusercontent.com/LujaMX/SSPIA/main/Actividad1/Plots/Plot_Contour.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘Plot_Contour.py’
#
# Plot_Contour.py     100%[===================>]     614  --.-KB/s    in 0s
#
# 2023-09-08 03:50:30 (34.7 MB/s) - ‘Plot_Contour.py’ saved [614/614]

# %% [markdown]
# Parámetros Funcion 1

# %%
f = lambda x, y: x * np.exp(-x**2 - y**2)

xl = np.array([-2, -2])
xu = np.array([2, 2])
x = np.array([-2, 2])

G = 1000
f_plot = np.zeros(G)
mu, sigma = 0, 0.2 # ES

# %% [markdown]
# Parametros funcion 2

# %%
#f = lambda x, y: x * np.exp(x+1) + y * np.exp(y+1)
f = lambda x, y: abs(x)**(1 + 1) + abs(y)**(2 + 1)


xl = np.array([-1, -1])
xu = np.array([1, 1])
x = np.array([-1, 1])

G = 1000
f_plot = np.zeros(G)
mu, sigma = 0, 0.2 # ES

# %% [markdown]
# # Random Search

# %%
for i in range(G):
    y = xl + (xu-xl) * np.random.random(2)

    display.display(plt.gcf())
    display.clear_output(wait=True)
    #plot_contour(f, x, y, xl, xu)

    if f(y[0], y[1]) < f(x[0], x[1]):
        x = y



    f_plot[i] = f(x[0], x[1])

plot_surf(f,x,xl,xu)
print("Mínimo global en x=", x[0], " y=", x[1], " f(x,y)=", f(x[0],x[1]))

plt.plot(range(G), f_plot)
plt.title("Convergencia")
# Out:
# Mínimo global en x= 0.01508485771781043  y= -0.006263836865519012  f(x,y)= 0.00022779869809176547
# Text(0.5, 1.0, 'Convergencia')

# %% [markdown]
# # ES

# %%
x = xl + (xu-xl) * np.random.random(2)
f_plot = np.zeros(G)

for i in range(G):
    r = np.random.normal(mu, sigma, 2)
    y = x + r

    if f(y[0], y[1]) < f(x[0], x[1]):
        x = y

    #display.display(plt.gcf())
    #display.clear_output(wait=True)
    #plot_contour(f, x, y, xl, xu)
    f_plot[i] = f(x[0], x[1])

plot_surf(f,x,xl,xu)
print("Mínimo global en x=", x[0], " y=", x[1], " f(x,y)=", f(x[0],x[1]))

plt.plot(range(G), f_plot)
plt.title("Convergencia")
# Out:
# Mínimo global en x= -0.00101167596303997  y= 0.007802903628216552  f(x,y)= 1.4985704217261458e-06
# Text(0.5, 1.0, 'Convergencia')

# %% [markdown]
# # Hill Climbing Random Mutation

# %%
x = xl + (xu-xl) * np.random.random(2)
f_plot = np.zeros(G)

for i in range(G):
    y = x.copy()
    j = np.random.randint(2)
    y[j] = xl[j] + (xu[j] - xl[j]) * np.random.random()

    if f(y[0], y[1]) < f(x[0], x[1]):
        x = y

    #display.display(plt.gcf())
    #display.clear_output(wait=True)
    #plot_contour(f, x, y, xl, xu)
    f_plot[i] = f(x[0], x[1])

plot_surf(f,x,xl,xu)
print("Mínimo global en x=", x[0], " y=", x[1], " f(x,y)=", f(x[0],x[1]))

plt.plot(range(G), f_plot)
plt.title("Convergencia")
# Out:
# Mínimo global en x= 0.0029395292089509084  y= -0.001376508570245072  f(x,y)= 8.643440145463455e-06
# Text(0.5, 1.0, 'Convergencia')
